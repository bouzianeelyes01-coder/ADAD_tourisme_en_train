# %%
import pandas as pd

# %%
df_tgvmax = pd.read_csv("tgvmax.csv",sep=";")

df_tgvmax
# Out:
#               DATE  TRAIN_NO      ENTITY      Axe Origine IATA  \
# 0       2025-12-12      5516  JCRHONRHIN      EST        FRXSK
# 1       2025-12-03      2778    SEDBARPA      EST        FRBFO
# 2       2025-12-06      5482    JCATLEST      EST        FRAET
# 3       2025-12-14      5486    JCESTATL      EST        FREAH
# 4       2025-12-04      7173     PAARRAS     NORD        FRPNO
# ...            ...       ...         ...      ...          ...
# 389712  2025-12-25      9898  JCRHONRHIN      EST        FRTJB
# 389713  2025-12-25      9898  JCRHONRHIN      EST        FRTJB
# 389714  2025-12-25      9898  JCRHONRHIN      EST        FRVLA
# 389715  2025-12-25      5781     PARAZUR  IC NUIT        FRPAZ
# 389716  2025-12-25      5781     PARAZUR  IC NUIT        FRPAZ
#
#        Destination IATA                           Origine  \
# 0                 FRAIE              ST RAPHAEL VALESCURE
# 1                 FRXCR                 VITRY LE FRANCOIS
# ...
